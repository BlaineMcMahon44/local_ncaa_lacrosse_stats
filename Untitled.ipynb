# %%
import pandas as pd 

df = pd.read_csv("/Users/bmcmahon/Desktop/mcm_alerts.csv")
df
# Out:
#                                 Task  \
# 0               CreateAndUpdateEcors
# 1                       processEcors
# 2                   ValidateEcorsXml
# 3     getMROMInputs-RemoteSiteShield
# 4                        ixnTopology
# ...                              ...
# 1437   Generate_InAddr_Dynamic_Pdata
# 1438   SiteShield-CidrConstrainedMap
# 1439      SROGeoPartitionerNewScores
# 1440            CreateAndUpdateEcors
# 1441       filterPreProvisionedSlots
#
#                                                   Alert        Date  \
# 0     Refusing to move Region 47481 which is in ecor...  2023-10-13
# 1     Refusing to move Region 47499 which is in ecor...  2023-10-13
# 2     Refusing to move Region 47499 which is in ecor...  2023-10-13
# 3                 process: runScript failed, returned 1  2023-10-13
# 4                 process: runScript failed, returned 1  2023-10-13
# ...                                                 ...         ...
# ...

# %%
df_no_duplicates = df.drop_duplicates(subset=['Task','Date'])

# %%
df_no_duplicates
# Out:
#                                 Task  \
# 0               CreateAndUpdateEcors
# 1                       processEcors
# 2                   ValidateEcorsXml
# 3     getMROMInputs-RemoteSiteShield
# 4                        ixnTopology
# ...                              ...
# 1437   Generate_InAddr_Dynamic_Pdata
# 1438   SiteShield-CidrConstrainedMap
# 1439      SROGeoPartitionerNewScores
# 1440            CreateAndUpdateEcors
# 1441       filterPreProvisionedSlots
#
#                                                   Alert        Date  \
# 0     Refusing to move Region 47481 which is in ecor...  2023-10-13
# 1     Refusing to move Region 47499 which is in ecor...  2023-10-13
# 2     Refusing to move Region 47499 which is in ecor...  2023-10-13
# 3                 process: runScript failed, returned 1  2023-10-13
# 4                 process: runScript failed, returned 1  2023-10-13
# ...                                                 ...         ...
# ...

# %%
df_no_duplicates['TaskFreq'] = df_no_duplicates.groupby('Task').cumcount() + 1
# Out:
# /var/folders/0d/s5kpzzp972ngjxs_czdjwr3r0000gn/T/ipykernel_95412/1141102482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_duplicates['TaskFreq'] = df_no_duplicates.groupby('Task').cumcount() + 1

# %%
df_no_duplicates
# Out:
#                                 Task  \
# 0               CreateAndUpdateEcors
# 1                       processEcors
# 2                   ValidateEcorsXml
# 3     getMROMInputs-RemoteSiteShield
# 4                        ixnTopology
# ...                              ...
# 1437   Generate_InAddr_Dynamic_Pdata
# 1438   SiteShield-CidrConstrainedMap
# 1439      SROGeoPartitionerNewScores
# 1440            CreateAndUpdateEcors
# 1441       filterPreProvisionedSlots
#
#                                                   Alert        Date  \
# 0     Refusing to move Region 47481 which is in ecor...  2023-10-13
# 1     Refusing to move Region 47499 which is in ecor...  2023-10-13
# 2     Refusing to move Region 47499 which is in ecor...  2023-10-13
# 3                 process: runScript failed, returned 1  2023-10-13
# 4                 process: runScript failed, returned 1  2023-10-13
# ...                                                 ...         ...
# ...
