# %%
df = pd.read_csv('/Users/bmcmahon/Desktop/Desktop/ncaa_lacrosse_stats/data/2024-01-15_15:31:48/Team_Data_2018_2019.csv', index_col = False)

# %%
df
# Out:
#      Unnamed: 0   Id        Team Name      Conference  Games  Goals  Assists  \
# 0             0  875  army west point         Patriot     13    117       72
# 1             1  885       bellarmine           SoCon     13    102       60
# 2             2   94       binghamton    America East     15    120       53
# 3             3  169         boston u         Patriot     17    171      116
# 4             4  756            brown      Ivy League     15    176      102
# ..          ...  ...              ...             ...    ...    ...      ...
# 133         133  574             utah  DI Independent     15    138       89
# 134         134  313          vermont    America East     15    173      103
# 135         135  432        villanova        Big East     15    170      102
# 136         136  978         virginia             ACC     20    282      172
# 137         137  197              vmi           SoCon     13    128       66
#
# ...
